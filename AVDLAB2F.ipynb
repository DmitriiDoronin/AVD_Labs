# %%
#Importing libraries
import numpy as np
import pandas as pd
from sklearn.datasets import make_swiss_roll
from sklearn import manifold, datasets
import matplotlib.pyplot as plt

# %%
#Initialiazing values
N_SAMPLES = 2000
NOISE = 0.5
RANDOM_SEED = 42

# %%
#Generating data
X, y = make_swiss_roll(n_samples=N_SAMPLES, noise=NOISE, random_state=RANDOM_SEED)
X
# Out:
# array([[-2.45685424,  5.40374645,  7.20128809],
#        [ 6.28169574,  4.62146542, 12.02240852],
#        [ 6.40255932, 19.16785155, -9.34299946],
#        ...,
#        [ 3.23939213,  7.25033003, -4.50054976],
#        [ 2.7577128 , 11.71262329, -4.35278077],
#        [ 4.87664105,  3.00119204,  6.818791  ]])

# %%
len(X),len(y)
# Out:
# (2000, 2000)

# %%
#Visualizing generated data
axes = [-11.5, 14, -2, 23, -12, 15]
fig = plt.figure(figsize=(11, 11))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.hot)
ax.view_init(10, -70)
ax.set_xlabel("$X_1$", fontsize=18)
ax.set_ylabel("$X_2$", fontsize=18)
ax.set_zlabel("$X_3$", fontsize=18)
ax.set_xlim(axes[0:2])
ax.set_ylim(axes[2:4])
ax.set_zlim(axes[4:6])

plt.show()

# %%
#Import and training PCA on dataset and normalization of data with standart scaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
#Standartization
#z = (x-mean(x)/sigma)
#z - score mean = 0, standart deviation = 1
X = StandardScaler().fit_transform(X)
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3'])
principalDf
# Out:
#       principal component 1  principal component 2  principal component 3
# 0                  0.461798               0.964955              -1.024434
# 1                  1.865108               0.654293              -0.593242
# 2                 -0.843892              -1.537576               1.107873
# 3                 -1.408208               1.378966               0.232916
# 4                  0.544194               0.556772               0.591252
# ...                     ...                    ...                    ...
# 1995              -1.369234               0.320714               0.763376
# 1996               1.693102               0.367692              -0.838343
# 1997              -0.208573               0.452708               0.686040
# 1998              -0.418611              -0.221254               0.474268
# 1999               1.263165               0.993939              -0.155229
#
# [2000 rows x 3 columns]

# %%
# Visualising data after PCA
fig = plt.figure(figsize=(11, 11))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(principalDf['principal component 1'], principalDf['principal component 2'], principalDf['principal component 3'], c=y, cmap=plt.cm.hot)
ax.view_init(10, -70)
ax.set_xlabel("$Component 1$", fontsize=18)
ax.set_ylabel("$Component 2$", fontsize=18)
ax.set_zlabel("$Component 3$", fontsize=18)
# Out:
# Text(0.5, 0, '$Component 3$')

# %%
# Out:
# array([0.37046783, 0.33259376, 0.29693842])

# %%
#Training local linear embedding alghorithm with diferent number of neighbours and printing error
sr_lle, sr_err = manifold.locally_linear_embedding(
       principalComponents, n_neighbors = 3, n_components=2
    )
print('Number of neighbors = ',3)
print(round(sr_err,20))

sr_lle, sr_err = manifold.locally_linear_embedding(
       principalComponents, n_neighbors = 4, n_components=2
    )
print('Number of neighbors = ',4)
print(round(sr_err,20))

sr_lle, sr_err = manifold.locally_linear_embedding(
       principalComponents, n_neighbors = 5, n_components=2
    )
print('Number of neighbors = ',5)
print(round(sr_err,20))

sr_lle, sr_err = manifold.locally_linear_embedding(
       principalComponents, n_neighbors = 6, n_components=2
    )
print('Number of neighbors = ',6)
print(round(sr_err,20))

sr_lle, sr_err = manifold.locally_linear_embedding(
       principalComponents, n_neighbors = 7, n_components=2
    )
print('Number of neighbors = ',7)
print(round(sr_err,20))

sr_lle, sr_err = manifold.locally_linear_embedding(
       principalComponents, n_neighbors = 8, n_components=2
    )
print('Number of neighbors = ',8)
print(round(sr_err,20))

sr_lle, sr_err = manifold.locally_linear_embedding(
       principalComponents, n_neighbors = 9, n_components=2
    )
print('Number of neighbors = ',9)
print(round(sr_err,20))

sr_lle, sr_err = manifold.locally_linear_embedding(
       principalComponents, n_neighbors = 10, n_components=2
    )
print('Number of neighbors = ',10)
print(round(sr_err,20))

sr_lle, sr_err = manifold.locally_linear_embedding(
       principalComponents, n_neighbors = 11, n_components=2
    )
print('Number of neighbors = ',11)
print(round(sr_err,20))

sr_lle, sr_err = manifold.locally_linear_embedding(
       principalComponents, n_neighbors = 12, n_components=2
    )
print('Number of neighbors = ',12)
print(round(sr_err,20))

sr_lle, sr_err = manifold.locally_linear_embedding(
       principalComponents, n_neighbors = 13, n_components=2
    )
print('Number of neighbors = ',13)
print(round(sr_err,20))

sr_lle, sr_err = manifold.locally_linear_embedding(
       principalComponents, n_neighbors = 14, n_components=2
    )
print('Number of neighbors = ',14)
print(round(sr_err,20))

sr_lle, sr_err = manifold.locally_linear_embedding(
       principalComponents, n_neighbors = 15, n_components=2
    )
print('Number of neighbors = ',15)
print(round(sr_err,20))
# Out:
# Number of neighbors =  3
# 5.73e-18
# Number of neighbors =  4
# -2.559e-17
# Number of neighbors =  5
# 7.97437805e-12
# Number of neighbors =  6
# 9.057592549e-11
# Number of neighbors =  7
# 2.0331138055e-10
# Number of neighbors =  8
# 4.1017073473e-10
# Number of neighbors =  9
# 2.70124718913e-09
# Number of neighbors =  10
# 5.92212441735e-09
# Number of neighbors =  11
# 4.66242955878e-09
# Number of neighbors =  12
# 6.23827158334e-09
# Number of neighbors =  13
# 8.7187682531e-09
# Number of neighbors =  14
# 1.12001020583e-08
# Number of neighbors =  15
# 1.687337372321e-08

# %%
#Training and visualizing t-SNE alghoritm
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, init='pca', random_state=501)
X_tsne = tsne.fit_transform(X)
X_tsne 
len(X_tsne)
# Out:
# 2000

# %%
fig = plt.figure()
fig.set_figheight(19)
fig.set_figwidth(23)
fig.subplots_adjust(hspace=0.5, wspace=0.5)

ax = fig.add_subplot(3, 3, 1)
for i in range(len(X_tsne)):
    plt.scatter(X_tsne[i][1], X_tsne[i][0],c='blue')
plt.xlabel("Component 1")
plt.ylabel("Component 2")
# Out:
# Text(0, 0.5, 'Component 2')

# %%
#Training and visualizing MDS alghoritm
from sklearn.manifold import MDS
mds = MDS(random_state=0)
X_MDS = mds.fit_transform(X)
X_MDS
# Out:
# array([[ 0.85244365,  1.00034458],
#        [ 2.14293582,  0.12770976],
#        [-1.19988179, -1.63328102],
#        ...,
#        [-0.07779721,  0.54369574],
#        [-0.40012339, -0.1190437 ],
#        [ 1.53281248,  0.65604794]])

# %%
fig = plt.figure()
fig.set_figheight(19)
fig.set_figwidth(23)
fig.subplots_adjust(hspace=0.5, wspace=0.5)

ax = fig.add_subplot(3, 3, 1)
for i in range(len(X_tsne)):
    plt.scatter(X_MDS[i][0], X_MDS[i][1],c='blue')
plt.xlabel("Component 1")
plt.ylabel("Component 2")
# Out:
# Text(0, 0.5, 'Component 2')

# %%
#Import digit dataset and visuzlizing digits
from sklearn.datasets import load_digits
from sklearn.preprocessing import MinMaxScaler
from matplotlib import offsetbox

digits = load_digits(n_class=6)
X, y = digits.data, digits.target
n_samples, n_features = X.shape
n_neighbors = 30
fig, axs = plt.subplots(nrows=10, ncols=10, figsize=(6, 6))
for idx, ax in enumerate(axs.ravel()):
    ax.imshow(X[idx].reshape((8, 8)), cmap=plt.cm.binary)
    ax.axis("off")
_ = fig.suptitle("A selection from the 64-dimensional digits dataset", fontsize=16)

# %%
#Initializing plot embedding function 
def plot_embedding(X, title):
    _, ax = plt.subplots()
    X = MinMaxScaler().fit_transform(X)

    for digit in digits.target_names:
        ax.scatter(
            *X[y == digit].T,
            marker=f"${digit}$",
            s=60,
            color=plt.cm.Dark2(digit),
            alpha=0.425,
            zorder=2,
        )
    shown_images = np.array([[1.0, 1.0]])  # just something big
    for i in range(X.shape[0]):
        # plot every digit on the embedding
        # show an annotation box for a group of digits
        dist = np.sum((X[i] - shown_images) ** 2, 1)
        if np.min(dist) < 4e-3:
            # don't show points that are too close
            continue
        shown_images = np.concatenate([shown_images, [X[i]]], axis=0)
        imagebox = offsetbox.AnnotationBbox(
            offsetbox.OffsetImage(digits.images[i], cmap=plt.cm.gray_r), X[i]
        )
        imagebox.set(zorder=1)
        ax.add_artist(imagebox)

    ax.set_title(title)
    ax.axis("off")

# %%
# Import from sklearn LDA,RandomTres,MDS,TSNE,SVD,LLE,ISOMAP
# Making dictionary with differernt embedding alghorithm
from sklearn.decomposition import TruncatedSVD
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomTreesEmbedding
from sklearn.manifold import (
    Isomap,
    LocallyLinearEmbedding,
    MDS,
    SpectralEmbedding,
    TSNE,
)
from sklearn.neighbors import NeighborhoodComponentsAnalysis
from sklearn.pipeline import make_pipeline
from sklearn.random_projection import SparseRandomProjection

embeddings = {
    "Random projection embedding": SparseRandomProjection(
        n_components=2, random_state=42
    ),
    "Truncated SVD embedding": TruncatedSVD(n_components=2),
    "Linear Discriminant Analysis embedding": LinearDiscriminantAnalysis(
        n_components=2
    ),
    "Isomap embedding": Isomap(n_neighbors=n_neighbors, n_components=2),
    "Standard LLE embedding": LocallyLinearEmbedding(
        n_neighbors=n_neighbors, n_components=2, method="standard"
    ),
    "Modified LLE embedding": LocallyLinearEmbedding(
        n_neighbors=n_neighbors, n_components=2, method="modified"
    ),
    "Hessian LLE embedding": LocallyLinearEmbedding(
        n_neighbors=n_neighbors, n_components=2, method="hessian"
    ),
    "LTSA LLE embedding": LocallyLinearEmbedding(
        n_neighbors=n_neighbors, n_components=2, method="ltsa"
    ),
    "MDS embedding": MDS(n_components=2, n_init=1, max_iter=120, n_jobs=2),
    "Random Trees embedding": make_pipeline(
        RandomTreesEmbedding(n_estimators=200, max_depth=5, random_state=0),
        TruncatedSVD(n_components=2),
    ),
    "Spectral embedding": SpectralEmbedding(
        n_components=2, random_state=0, eigen_solver="arpack"
    ),
    "t-SNE embeedding": TSNE(
        n_components=2,
        n_iter=500,
        n_iter_without_progress=150,
        n_jobs=2,
        random_state=0,
    ),
    "NCA embedding": NeighborhoodComponentsAnalysis(
        n_components=2, init="pca", random_state=0
    ),
}

# %%
# Loop which training all embedding algorithms and starting with LDA
from time import time

projections, timing = {}, {}
for name, transformer in embeddings.items():
    if name.startswith("Linear Discriminant Analysis"):
        data = X.copy()
        data.flat[:: X.shape[1] + 1] += 0.01  # Make X invertible
    else:
        data = X

    print(f"Computing {name}...")
    start_time = time()
    projections[name] = transformer.fit_transform(data, y)
    timing[name] = time() - start_time
# Out:
# Computing Random projection embedding...
# Computing Truncated SVD embedding...
# Computing Linear Discriminant Analysis embedding...
# Computing Isomap embedding...
# Computing Standard LLE embedding...
# Computing Modified LLE embedding...
# Computing Hessian LLE embedding...
# Computing LTSA LLE embedding...
# Computing MDS embedding...
# Computing Random Trees embedding...
# Computing Spectral embedding...
# Computing t-SNE embeedding...
# Computing NCA embedding...

# %%
# Plot of digit embedding 
for name in timing:
    title = f"{name} (time {timing[name]:.3f}s)"
    plot_embedding(projections[name], title)

plt.show()

# %%
#Import KNN classifier

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
#Cross validation
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=0)

# %%
#Training KNN classifier with 5 neighbors

knn=KNeighborsClassifier(n_neighbors=5,metric='euclidean',p=4)
knn.fit(X_train,y_train)
y_pred=knn.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, 2, 3, 5, 1, 1, 3, 4, 2, 5, 1, 1, 3, 0, 4, 4, 0, 4, 2, 1,
#        4, 0, 0, 5, 3, 1, 2, 5, 1, 1, 0, 2, 4, 2, 3, 5, 1, 1, 4, 2, 4, 4,
#        1, 0, 1, 4, 2, 0, 0, 5, 4, 0, 4, 0, 1, 4, 4, 4, 5, 2, 1, 4, 0, 4,
#        2, 0, 2, 0, 4, 4, 1, 5, 0, 1, 3, 0, 4, 1, 4, 0, 5, 2, 5, 0, 0, 2,
#        4, 2, 5, 1, 5, 5, 5, 4, 5, 4, 2, 3, 2, 4, 0, 3, 3, 4, 5, 0, 3, 0,
#        1, 5, 0, 1, 4, 5, 2, 3, 2, 4, 0, 5, 2, 2, 4, 5, 2, 3, 4, 3, 5, 5,
#        5, 4, 3, 2, 0, 4, 2, 3, 2, 0, 1, 2, 3, 5, 2, 5, 2, 5, 3, 1, 0, 3,
#        1, 2, 0, 2, 5, 3, 3, 1, 2, 3, 4, 4, 4, 5, 5, 1, 4, 5, 4, 0, 0, 5,
#        5, 2, 1, 2, 1, 2, 5, 5, 0, 2, 4, 0, 0, 1, 5, 0, 3, 3, 0, 2, 0, 5,
#        5, 3, 0, 2, 2, 5, 1, 0, 5, 0, 1, 3, 3, 2, 0, 4, 0, 5, 1])

# %%
#accuracy score
score=accuracy_score(y_test,y_pred)
score
# Out:
# 0.9953917050691244

# %%
#Confusion matrix of KNN classifier
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
#KNN training with different embeddigs
for name in timing:
    title = f"{name} (time {timing[name]:.3f}s)"
    plot_embedding(projections[name], title)
    X_train, X_test, y_train, y_test = train_test_split(projections[name], y,test_size=0.2,random_state=0)
    knn=KNeighborsClassifier(n_neighbors=5,metric='chebyshev',p=4)
    knn.fit(X_train,y_train)
    y_pred=knn.predict(X_test)
    score=accuracy_score(y_test,y_pred)
    print('Accuracy = ',score)
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(10,7))
    sns.heatmap(cm, annot=True)s
    plt.xlabel('Predicted')
    plt.ylabel('Truth')
    plt.show()
# Out:
# Accuracy =  0.3824884792626728
# Accuracy =  0.5944700460829493
# Accuracy =  0.9308755760368663
# Accuracy =  0.8663594470046083
# Accuracy =  0.6129032258064516
# Accuracy =  0.9124423963133641
# Accuracy =  0.9216589861751152
# Accuracy =  0.9262672811059908
# Accuracy =  0.8341013824884793
# Accuracy =  0.5668202764976958
# Accuracy =  0.9308755760368663
# Accuracy =  0.9953917050691244
# Accuracy =  0.880184331797235
