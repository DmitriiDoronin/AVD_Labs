# %%
# Importing Required Libraries
import numpy as np
import matplotlib.pyplot as plt

# Generating x-axis data using arange function from numpy
xdata = np.arange(-19,120, 0.01)
constant = 0.8

# Finding y-axis for each x-data using log(xdata)
ydata =-np.log((5/10)*(1+(xdata/20)))*100+xdata*0.08

# Plotting xdata vs ydata using plot function from pyplot
plt.xticks(np.arange(-20,120, 5))
plt.yticks(np.arange(-100,360, 10))
plt.plot(xdata, ydata)

# Settng title for the plot in blue color
plt.title('Logarithmic Curve', color='b')

# Setting x axis label for the plot
plt.xlabel('X'+ r'$\rightarrow$')

# Setting y axis label for the plot
plt.ylabel('Y '+ r'$\rightarrow$')

# Showing grid
plt.grid()

# Highlighting axis at x=0 and y=0
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

# Finally displaying the plot
plt.show()

# %%
len(xdata)
# Out:
# 13900

# %%
# Generating x-axis data using arange function from numpy
xdata = np.arange(-19,20, 0.01)
constant = 0.8

# Finding y-axis for each x-data using log(xdata)
ydata = np.exp(-1/14*xdata+0.0035*xdata)*100

# Plotting xdata vs ydata using plot function from pyplot
plt.xticks(np.arange(-20,0, 2))
plt.yticks(np.arange(0,370, 10))
plt.plot(xdata, ydata)

# Settng title for the plot in blue color
plt.title('exp Curve', color='b')

# Setting x axis label for the plot
plt.xlabel('X'+ r'$\rightarrow$')

# Setting y axis label for the plot
plt.ylabel('Y '+ r'$\rightarrow$')

# Showing grid
plt.grid()

# Highlighting axis at x=0 and y=0
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

# Finally displaying the plot
plt.show()
