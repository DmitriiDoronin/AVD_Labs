# %%
#Importing librarie and reading data from csv file
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
iris = pd.read_csv('Iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#Dimension of dataset
iris.shape
# Out:
# (150, 6)

# %%
#Descriptive statisitcs of data
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#Info about dataset
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#Counting of null
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#Counting number of target values
iris['Species'].value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %%
print(iris[:]['Species'])
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
#Introduction data in the matrix
X_matrix = [[1, -1, 2],
            [2, 0, 0],
            [0, 1, -1]]
X_matrix
# Out:
# [[1, -1, 2], [2, 0, 0], [0, 1, -1]]

# %%
#mean computing
average = np.average(X_matrix)
average
# Out:
# 0.4444444444444444

# %%
#variance computing
variance = np.var(X_matrix)
variance
# Out:
# 1.1358024691358024

# %%
#Import and normalization of data with MinMax scaler
from sklearn.preprocessing import MinMaxScaler
#minmax scaler
#xi = (x-min(x))/(max(x)-min(x)) 
#--->[0,1]
MinMax = MinMaxScaler()
X_matrix1 = MinMax.fit_transform(X_matrix)
X_matrix1
# Out:
# array([[0.5       , 0.        , 1.        ],
#        [1.        , 0.5       , 0.33333333],
#        [0.        , 1.        , 0.        ]])

# %%
#Import and normalization of data with Standart scaler
from sklearn.preprocessing import StandardScaler
#Standartization
#z = (x-mean(x)/sigma)
#z - score mean = 0, standart deviation = 1
StScaler = StandardScaler()
X_matrix2 = StScaler.fit_transform(X_matrix)
X_matrix2
# Out:
# array([[ 0.        , -1.22474487,  1.33630621],
#        [ 1.22474487,  0.        , -0.26726124],
#        [-1.22474487,  1.22474487, -1.06904497]])

# %%
#Computing mean and averagr afte MinMaxscaler
average1 = np.average(X_matrix1)
variance1 = np.var(X_matrix1)
print('Mean after MinMaxScaler = ' ,round(average1, 2))
print('Variance after MinMaxScaler = ', round(variance1, 2))
# Out:
# Mean after MinMaxScaler =  0.48
# Variance after MinMaxScaler =  0.17

# %%
#Computing mean and averagr afte StandartScaler
average2 = np.average(X_matrix2)
variance2 = np.var(X_matrix2)
print('Mean after MinMaxScaler = ' ,round(average2, 2))
print('Variance after MinMaxScaler = ', round(variance2, 2))
# Out:
# Mean after MinMaxScaler =  0.0
# Variance after MinMaxScaler =  1.0

# %%
fig = plt.figure()
fig.set_figheight(19)
fig.set_figwidth(23)
fig.subplots_adjust(hspace=0.5, wspace=0.5)
ax = fig.add_subplot(3, 3, 1)
colors = {'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'}
for i in range(len(iris['SepalLengthCm'])):
    plt.scatter(iris['SepalLengthCm'][i], iris['SepalWidthCm'][i],c=colors[iris['Species'][i]])
plt.xlabel("Sepal Length Cm")
plt.ylabel("Sepal Width Cm")

ax = fig.add_subplot(3, 3, 2)
for i in range(len(iris['SepalLengthCm'])):
   plt.scatter(iris['SepalLengthCm'][i], iris['PetalLengthCm'][i],c=colors[iris['Species'][i]])
plt.xlabel("Sepal Length Cm")
plt.ylabel("Petal Lenght Cm")

ax = fig.add_subplot(3, 3, 3)
for i in range(len(iris['SepalLengthCm'])):
    plt.scatter(iris['SepalLengthCm'][i], iris['PetalWidthCm'][i],c=colors[iris['Species'][i]])
plt.xlabel("Sepal Length Cm")
plt.ylabel("Petal Width Cm")

ax = fig.add_subplot(3, 3, 5)
for i in range(len(iris['SepalWidthCm'])):
    plt.scatter(iris['SepalWidthCm'][i], iris['PetalWidthCm'][i],c=colors[iris['Species'][i]])
plt.xlabel("Sepal Width Cm")
plt.ylabel("Petal Width Cm")

ax = fig.add_subplot(3, 3, 6)
for i in range(len(iris['SepalLengthCm'])):
    plt.scatter(iris['SepalWidthCm'][i], iris['PetalLengthCm'][i],c=colors[iris['Species'][i]])
plt.xlabel("Sepal Width Cm")
plt.ylabel("Petal Length Cm")

ax = fig.add_subplot(3, 3, 9)
for i in range(len(iris['PetalLengthCm'])):
    plt.scatter(iris['PetalLengthCm'][i], iris['PetalWidthCm'][i],c=colors[iris['Species'][i]])
plt.xlabel("Petal Length Cm")
plt.ylabel("Petal Width Cm")
# Out:
# Text(0, 0.5, 'Petal Width Cm')

# %%
#Iris correlation table
iris.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
#Training data
features = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
X = iris.loc[:, features].values

# %%
#Importing PCA module from sklearn and training on Iris data with 3 components
from sklearn.decomposition import PCA

X = StandardScaler().fit_transform(X)
pca = PCA(n_components=3)
Y = iris.loc[:,['Species']].values
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3'])
finalDf = pd.concat([principalDf, iris[['Species']]], axis = 1)
finalDf.head(7)
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0              -2.264542               0.505704              -0.121943
# 1              -2.086426              -0.655405              -0.227251
# 2              -2.367950              -0.318477               0.051480
# 3              -2.304197              -0.575368               0.098860
# 4              -2.388777               0.674767               0.021428
# 5              -2.070537               1.518549               0.030684
# 6              -2.445711               0.074563               0.342198
#
#        Species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa
# 5  Iris-setosa
# 6  Iris-setosa

# %%
pca.explained_variance_ratio_.round(2)
# Out:
# array([0.73, 0.23, 0.04])

# %%
fig = plt.figure()
fig.set_figheight(19)
fig.set_figwidth(23)
fig.subplots_adjust(hspace=0.5, wspace=0.5)

axe = fig.add_subplot(3, 3, 1)
xaxe = list(range(-75,75,1))
colors = {'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'}
for i in range(len(finalDf['principal component 1'])):
    plt.scatter(xaxe[i],finalDf['principal component 1'][i], c=colors[finalDf['Species'][i]])
plt.xlabel("Index")
plt.ylabel("principal component 1")

axe = fig.add_subplot(3, 3, 2)
for i in range(len(finalDf['principal component 1'])):
    plt.scatter(xaxe[i],finalDf['principal component 2'][i], c=colors[finalDf['Species'][i]])
plt.xlabel("Index")
plt.ylabel("principal component 2")

axe = fig.add_subplot(3, 3, 3)
for i in range(len(finalDf['principal component 1'])):
    plt.scatter(xaxe[i],finalDf['principal component 3'][i], c=colors[finalDf['Species'][i]])
plt.xlabel("Index")
plt.ylabel("principal component 3")

axe = fig.add_subplot(3, 3, 5)
for i in range(len(finalDf['principal component 1'])):
    plt.scatter(finalDf['principal component 1'][i], finalDf['principal component 2'][i],c=colors[finalDf['Species'][i]])
plt.xlabel("principal component 1")
plt.ylabel("principal component 2")
# Out:
# Text(0, 0.5, 'principal component 2')

# %%
from mpl_toolkits.mplot3d import Axes3D
import pylab
iris['Species']=pd.Categorical(iris['Species'])
my_color=iris['Species'].cat.codes
fig = pylab.figure()
ax = Axes3D(fig)
iris['Species']=pd.Categorical(iris['Species'])
my_color=iris['Species'].cat.codes
ax.scatter(finalDf['principal component 1'] ,finalDf['principal component 2'],xaxe[i],c=my_color, cmap="Set1_r", s=75)
plt.xlabel("principal component 1")
plt.ylabel("principal component 2")
plt.show()

# %%
#Importing LDA module from sklearn and training on Iris data with 2 components
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
X= iris.loc[:, features].values
X = StandardScaler().fit_transform(X)
Y = iris.loc[:,['Species']].values
Y  = np.ravel(Y,order='A')
lda = LDA(n_components=2)
X_train = lda.fit_transform(X, Y)
LDA_Df = pd.DataFrame(data = X_train
             , columns = ['component 1', 'component 2'])
final_LDA_Df = pd.concat([LDA_Df, iris[['Species']]], axis = 1)

# %%
fig = pylab.figure()
ax = Axes3D(fig)
iris['Species']=pd.Categorical(iris['Species'])
my_color=iris['Species'].cat.codes
ax.scatter(final_LDA_Df['component 1'] ,final_LDA_Df['component 2'],xaxe[i],c=my_color, cmap="Set1_r", s=75)
plt.xlabel(" component 1")
plt.ylabel(" component 2")
plt.show()
lda.explained_variance_ratio_.round(3)
# Out:
# array([0.991, 0.009])

# %%
fig = plt.figure()
fig.set_figheight(19)
fig.set_figwidth(20)
fig.subplots_adjust(hspace=0.5, wspace=0.5)

axe = fig.add_subplot(3, 3, 1)
for i in range(len(final_LDA_Df[ 'component 1'])):
    plt.scatter(xaxe[i],final_LDA_Df['component 1'][i], c=colors[finalDf['Species'][i]])
plt.xlabel("Index")
plt.ylabel("component 1")

axe = fig.add_subplot(3, 3, 2)
for i in range(len(final_LDA_Df[ 'component 1'])):
    plt.scatter(xaxe[i],final_LDA_Df['component 2'][i], c=colors[finalDf['Species'][i]])
plt.xlabel("Index")
plt.ylabel("component 2")

axe = fig.add_subplot(3, 3, 3)
for i in range(len(final_LDA_Df[ 'component 1'])):
    plt.scatter(final_LDA_Df[ 'component 1'][i],final_LDA_Df['component 2'][i], c=colors[finalDf['Species'][i]])
plt.xlabel("component 1")
plt.ylabel("component 2")
# Out:
# Text(0, 0.5, 'component 2')

# %%
#Visualising distribution of data
import seaborn as sns
sns.FacetGrid(iris, hue="Species", height=5).map(sns.kdeplot, 'SepalLengthCm').add_legend()
sns.FacetGrid(iris, hue="Species", height=5).map(sns.kdeplot, 'SepalWidthCm').add_legend()
sns.FacetGrid(iris, hue="Species", height=5).map(sns.kdeplot, 'PetalLengthCm').add_legend()
sns.FacetGrid(iris, hue="Species", height=5).map(sns.kdeplot, 'PetalWidthCm').add_legend()

# %%
#Importing FastICA module from sklearn and training on Iris data with 2 components 
from sklearn.decomposition import FastICA
F_ICA = FastICA(n_components=2, random_state=0, whiten='unit-variance')
X_transformed = F_ICA.fit_transform(X)
ICA_Df = pd.DataFrame(data = X_transformed
             , columns = ['component 1', 'component 2'])
final_ICA_Df = pd.concat([ICA_Df, iris[['Species']]], axis = 1)
final_ICA_Df
# Out:
#      component 1  component 2         Species
# 0       0.106742    -0.046924     Iris-setosa
# 1       0.101808     0.052094     Iris-setosa
# 2       0.114232     0.022962     Iris-setosa
# 3       0.111976     0.044912     Iris-setosa
# 4       0.112162    -0.061513     Iris-setosa
# ..           ...          ...             ...
# 145    -0.090641    -0.029296  Iris-virginica
# 146    -0.071741     0.079670  Iris-virginica
# 147    -0.073559    -0.020040  Iris-virginica
# 148    -0.068964    -0.084014  Iris-virginica
# 149    -0.045810     0.003560  Iris-virginica
#
# [150 rows x 3 columns]

# %%
fig = plt.figure()
fig.set_figheight(19)
fig.set_figwidth(20)
fig.subplots_adjust(hspace=0.5, wspace=0.5)

axe = fig.add_subplot(3, 3, 1)
for i in range(len(final_ICA_Df[ 'component 1'])):
    plt.scatter(xaxe[i],final_ICA_Df['component 1'][i], c=colors[final_ICA_Df['Species'][i]])
plt.xlabel("Index")
plt.ylabel("component 1")

axe = fig.add_subplot(3, 3, 2)
for i in range(len(final_ICA_Df[ 'component 2'])):
    plt.scatter(xaxe[i],final_ICA_Df['component 2'][i], c=colors[final_ICA_Df['Species'][i]])
plt.xlabel("Index")
plt.ylabel("component 1")

axe = fig.add_subplot(3, 3, 3)
for i in range(len(final_ICA_Df[ 'component 1'])):
    plt.scatter(final_ICA_Df['component 1'][i],final_ICA_Df['component 2'][i], c=colors[final_ICA_Df['Species'][i]])
plt.xlabel("component 1")
plt.ylabel("component 2")
# Out:
# Text(0, 0.5, 'component 2')

# %%
# Importing and visualising MNIST dataset
from matplotlib import pyplot
from scipy.io import loadmat

mnist = loadmat("mnist-original.mat")
mnist_data = mnist["data"].T
mnist_label = mnist["label"][0]

def load_mnist_dataset():

    mnist = loadmat("mnist-original.mat")
    mnist_data = mnist["data"].T
    mnist_data = mnist_data.reshape(len(mnist_data), 28, 28, 1)
    mnist_label = mnist["label"][0]
    count = len(set(mnist_label))
    return mnist_data, mnist_label, count, (28, 28, 1)
# Download data from MNIST-original dataset
data, labels, classes_count, data_shape = load_mnist_dataset()
print("data shape: " + str(data.shape))
print("labels shape: " + str(labels.shape))
print("classes count: " + str(classes_count))
def plot_images_sample(X, Y):
    # Draw plot for images sample
    
    plt.figure(figsize=(10,10))
    rand_indicies = np.random.randint(len(X), size=25)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        index = rand_indicies[i]
        plt.imshow(np.squeeze(X[index]), cmap=plt.cm.binary)
        plt.xlabel(Y[index])
    plt.show()
# Draw plot for images sample
plot_images_sample(data, labels)
# Out:
# data shape: (70000, 28, 28, 1)
# labels shape: (70000,)
# classes count: 10
